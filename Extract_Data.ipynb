# %%
# !pip install boto3

# %%
import boto3

# %%
s3 = boto3.resource(
    service_name='s3',
    region_name='eu-central-1',
    aws_access_key_id='AKIAT4LQVV2YTQML7YJC',
    aws_secret_access_key='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'
)

# %%
for bucket in s3.buckets.all():
    print(bucket.name)
# Out:
# acfs3codemenschen
# codefactory-acfs3
# codemenschen-machine-learning
# codemenschen1
# gift-card-pro
# portalgmbh
# strykerlabs-general

# %%
for obj in s3.Bucket('strykerlabs-general').objects.all():
    print(obj)
# Out:
# s3.ObjectSummary(bucket_name='strykerlabs-general', key='Rohdaten_Tracking/')
# s3.ObjectSummary(bucket_name='strykerlabs-general', key='Rohdaten_Tracking/Hartberg/')
# s3.ObjectSummary(bucket_name='strykerlabs-general', key='Rohdaten_Tracking/Hartberg/210104/')
# s3.ObjectSummary(bucket_name='strykerlabs-general', key='Rohdaten_Tracking/Hartberg/210104/Session-A. Lienhart-4-1-2021 Session-Tijani-4-1-2021_ExtendedRawData.csv')
# s3.ObjectSummary(bucket_name='strykerlabs-general', key='Rohdaten_Tracking/Hartberg/210105/')
# s3.ObjectSummary(bucket_name='strykerlabs-general', key='Rohdaten_Tracking/Hartberg/210105/Session-A. Lienhart-5-1-2021 Session-Tijani-5-1-2021_ExtendedRawData.csv')
# s3.ObjectSummary(bucket_name='strykerlabs-general', key='Rohdaten_Tracking/Hartberg/210105/Session-A. Lienhart-5-1-2021 Session-Tijani-5-1-2021_ExtendedRawData2.csv')
# s3.ObjectSummary(bucket_name='strykerlabs-general', key='Rohdaten_Tracking/Hartberg/210106/')
# ...

# %%
import pandas as pd

# %%
obj = s3.Bucket('strykerlabs-general').Object('Rohdaten_Tracking/Hartberg/210104/Session-A. Lienhart-4-1-2021 Session-Tijani-4-1-2021_ExtendedRawData.csv').get()
foo = pd.read_csv(obj['Body'], index_col=0)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/lib/arraysetops.py:580: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
foo
# Out:
#            Player Display Name  ...   No. of Satellites
# Player Id                       ...
# 1201               A. Lienhart  ...                  22
# 1201               A. Lienhart  ...                  22
# 1201               A. Lienhart  ...                  22
# 1201               A. Lienhart  ...                  22
# 1201               A. Lienhart  ...                  22
# ...                        ...  ...                 ...
# 1245                    Tijani  ...                  21
# 1245                    Tijani  ...                  21
# 1245                    Tijani  ...                  21
# 1245                    Tijani  ...                  21
# 1245                    Tijani  ...                  21
#
# [11886363 rows x 19 columns]
